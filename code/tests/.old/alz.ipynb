# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import pandas as pd
import seaborn as sns
import plotter as p
import jupyter as j
import plotter3 as p3
import importlib
# Out:
# custom jupyter @DanielRobinson

# %% [markdown]
# https://www.poughkeepsiejournal.com/story/life/2015/10/30/legal-wills-estate-planning-families/74869736/
#
# What kinds of documents might be involved? There are a variety of contexts in which capacity can be difficult to assess, including (but not limited to):
#
# * Ability to sign a contract — say to buy a car or build a home.
# * Understanding of a power of attorney, which might give the authority to another person to sign future documents.
# * Capacity to get married (which is, after all, a specialized kind of contract).
# * Ability to make medical decisions — including refusing medication, or either seeking or declining mental health treatment.
# * Capacity to sign a trust.
# * Capacity to sign a will.
#
# Levels required?
# * The capacity level required to sign a trust is generally thought to be similar to the level of capacity to sign a contract.
# * The capacity to sign a will is generally considered the lowest level of capacity required to sign any legal document in New York.

# %% [markdown]
# Even though he may have had testamentory capacity to sign a will, it is very likely that he was unduly influenced by his last wife due to Dementia / Alzheimers. It seems the law does not see her making her wishes known to him as objectionable (not legally at least), but for the fact that her wishes were substituted for his it is seen as "undue" influence in the eyes of the law. Pre-diagnosis and at testamentory capacity, it can be argued that he had little intention of changing his will to benefit her and disinherit his children. If he wanted to disinherit his children, he would have directed his estate elsewhere (charity, friends, other family etc). In this case, the will is "her" will and his as the great man he was wishes are not made known. He is a great man, but 'was' is used to indicate the decline in mental capacity to that of a child that can be easily influenced or manipulated by those close to him. Even if this analogy is not used, his independance in simple daily tasks had deteriorated, and changing the will may have made his situation better to silence the haranguing / influence of his late wife without realizing what he is "doing".
#
# If a dog or cat got a new owner at the last stage of its life, and food every day, it will do anything for that food, even if it loses its memory.

# %% [markdown]
# * jan 2011
# * jan 2018
# * 7 year period
# * 90s
# * 95 died
# * categorical
# * equally divided
# * 2012 will changed 20 April
# * judgement was impaired
# * 450 500 million
# * close
# * stable variables

# %%
plt.plot([2002, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], [1.0, 0.95, 0.9, 0.81, 0.69, 0.59, 0.51, 0.41, 0.35, 0.30, 0.28, 0.27], label='Mental Capacity')
plt.plot([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], [0.0, 0.5, 0.55, 0.61, 0.55, 0.6, 0.54, 0.59], label='Undue Influence')
plt.plot([2002, 2010, 2011, 2014, 2015, 2016, 2017, 2018], [0.2, 0.215, 0.3, 0.31, 0.32, 0.33, 0.35, 0.36], label='Family Influence')
plt.plot([2002, 2010, 2011, 2013, 2014], [1.0, 0.98, 0.5, 0.31, 0.1], label='Signature deterioration')
plt.xlabel('year')
plt.ylabel('Probability')
plt.title('Effect of Alzheimers over time')
plt.legend()
plt.savefig('alzheimers.pdf')
plt.savefig('alzheimers.png')

# %%
plt.plot([2014, 2015, 2016, 2017, 2018], [0.41, 0.35, 0.30, 0.28, 0.27])
plt.xlabel('year')
plt.ylabel('Mental Capacity')
plt.title('Mental Capacity deterioration over time')
# Out:
# Text(0.5, 1.0, 'Mental Capacity deterioration over time')

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(14,6))
plt.rcParams.update({'font.family': 'DejaVu Sans'})
plt.rcParams.update({'font.weight': 'normal'})
plt.rcParams.update({'font.size': 22})
x = [2010.9, 2011.4, 2011.9, 2012.22, 2012.9, 2014.1, 2015.1, 2015.9, 2016.5, 2017.2, 2017.6]
y = [29, 28, 27, 24, 24, 21, 18, 11, 11, 8, 4]
plt.plot(x, y, 'b--o', label='MMSE',
        linewidth=4, markersize=12)
plt.xlabel('Year')
plt.ylabel('Mini-Mental State Examination Score')
plt.title('Effect of Alzheimers over time')
ax = plt.gca()
ax.set_ylim(None, 34)
ax.set_xlim(2010.5, 2018)
ax.fill_between([2010.5, *x, 2018], 26, 30, color='green')
ax.fill_between([2010.5, *x, 2018], 20, 26, color='yellow')
ax.fill_between([2010.5, *x, 2018], 10, 20, color='orange')
ax.fill_between([2010.5, *x, 2018], 0, 10, color='red')
plt.rcParams.update({'font.weight': 'bold'})
for year, score in zip(x, y):
    offx=-0.15
    offy=-2.5
    plt.annotate(score, (year+offx, score+offy))
plt.legend()
plt.rcParams.update({'font.size': 18})
ax.annotate("Delirium", xy=(2010.95, 29), xytext=(2011.8, 30.9), arrowprops=dict(arrowstyle="->", lw=3))
ax.annotate("", xy=(2011.2, 28.5), xytext=(2011.8, 30.9), arrowprops=dict(arrowstyle="->", lw=3))
ax.annotate("Undue Influence", xy=(2012.5, 23.9), xytext=(2011.8, 18), arrowprops=dict(arrowstyle="->", lw=3))
ax.annotate("Myocardial Infarction", xy=(2012.4, 23.9), xytext=(2011.5, 12), arrowprops=dict(arrowstyle="->", lw=3))
plt.rcParams.update({'font.size': 20})
ax.text(2010.6, 22, 'Mild')
ax.text(2010.6, 14.5, 'Moderate')
ax.text(2010.6, 5.5, 'Frail Care')
plt.savefig('mmse_alzheimers.pdf')
plt.savefig('mmse_alzheimers.png')

# %%
ax.text?
# Out:
# Signature: ax.text(x, y, s, fontdict=None, withdash=<deprecated parameter>, **kwargs)
# Docstring:
# Add text to the axes.
#
# Add the text *s* to the axes at location *x*, *y* in data coordinates.
#
# Parameters
# ----------
# x, y : scalars
#     The position to place the text. By default, this is in data
#     coordinates. The coordinate system can be changed using the
#     *transform* parameter.
#
# s : str
#     The text.
#
# fontdict : dictionary, optional, default: None
#     A dictionary to override the default text properties. If fontdict
#     is None, the defaults are determined by your rc parameters.
#
# withdash : boolean, optional, default: False
#     Creates a `~matplotlib.text.TextWithDash` instance instead of a
#     `~matplotlib.text.Text` instance.
#
# Returns
# -------
# text : `.Text`
#     The created `.Text` instance.
#
# Other Parameters
# ----------------
# **kwargs : `~matplotlib.text.Text` properties.
#     Other miscellaneous text parameters.
#
# ...

# %%
plt.plot?
# Out:
# Signature: plt.plot(*args, scalex=True, scaley=True, data=None, **kwargs)
# Docstring:
# Plot y versus x as lines and/or markers.
#
# Call signatures::
#
#     plot([x], y, [fmt], *, data=None, **kwargs)
#     plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
# The coordinates of the points or line nodes are given by *x*, *y*.
#
# The optional parameter *fmt* is a convenient way for defining basic
# formatting like color, marker and linestyle. It's a shortcut string
# notation described in the *Notes* section below.
#
# >>> plot(x, y)        # plot x and y using default line style and color
# >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
# >>> plot(y)           # plot y using x as index array 0..N-1
# >>> plot(y, 'r+')     # ditto, but with red plusses
#
# You can use `.Line2D` properties as keyword arguments for more
# control on the appearance. Line properties and *fmt* can be mixed.
# The following two calls yield identical results:
#
# ...
