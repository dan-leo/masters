# %%
import numpy as np
import matplotlib.pyplot as plt
import jupyter as j
import importlib
import pandas as pd
import seaborn as sns
importlib.reload(j)

import matplotlib.ticker as ticker
import glob

import plotter as p
importlib.reload(p)

dirrs = ['logs/zte_mtn/rf_shield/ublox/', 'logs/zte_mtn/rf_shield/quectel/', 'logs/nokia_vodacom/centurycity/ublox/', 'logs/nokia_vodacom/centurycity/quectel/']
# Out:
# custom jupyter @DanielRobinson

# %%
print('ublox zte', sum([26,18,20,19,56,16,12,12,12,35,16,12,12,12,34,11,14,12,14,45,9,8,6,7,37,13,27,17,13,62,12,10,10,10,21,]))
# Out:
# ublox zte 670

# %%
kx = 'txTime'
ky = 'energy'
title = 'all energy vs latency'
limited=False
threshs = [[None, None, None, None], [None, None, None, None], [None, 15000, None, None], [None, 15000, None, None]]
# threshs = [[3000, None, None, None], [3000, None, None, None], [10000, None, None, None], [15000, None, None, None]]
importlib.reload(p)
importlib.reload(j)
scales = [[1, 1], [1, 1], [1000, 1000], [1000, 1000]]
scale2s = [[1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000]]
scale3s = [[1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000]]
plotlims = [[1,  30, 1, 40], [1,  16, 1, 30], [1,  250, 1, 400], [1,  250, 1, 400]]
plotlim2s = [[100,  135, 2, 2.8], [1,  200, None, None], [1,  200, None, None], [1,  200, None, None]]
plotlim3s = [[1,  3, 200, 2000], [0.7,  3, 100, 2000], [3,  10, 1, 20], [3,  10, 1, 20]]

for dirr, scale, scale2, scale3, plotlim, plotlim2, plotlim3, thresh in zip(dirrs, scales, scale2s, scale3s, plotlims, plotlim2s, plotlim3s, threshs):
    print('########################################################################################################################')
    dirr = [dirr]
    dgrams = [1, 16, 64, 128, 256, 512]
    cc = ['tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:blue', 'tab:brown', 'tab:cyan']
    fig = plt.figure(figsize=(5, 3))
    plt.title(title + ' plot')
    files = [['release/release0/*', 'release/release1/*','release/release16/*'],['release/release64/*','release/release128/*'],['release/release256/*','release/release512/*']]
    files.append(['echo/deregister/*', 'echo/e/*', 'echo/echo/*', 'echo/register/*'])
    files.append(['cops/delay/*', 'cops/deregister/*', 'cops/release/*', 'cops/tensec/*'])
    files.append(['drx/cap/*'])
    files.append(['ptau/capture/*'])
    labs = ['1-16 B', '64-128 B', '256-512 B', 'echo', 'cops', 'drx', 'ptau']
    for i in range(len(files)):
        p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim, scale, limited, dirr, files[i], scaled=False, log=False, overlay=True, labels=[labs[i]], legend=True, ttype='single', fig=fig, colour=cc[i]) #, bbox=(1.05, 0.9))
#     print(plt.xticks())
    plt.show()
    
#     fig = plt.figure(figsize=(5, 3))
#     plt.title(title + ' plot')
#     labs = ['drx2']
#     for i in range(len(files)):
#         p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim2, scale, True, dirr, files[i], log=False, overlay=True, labels=[labs[i]], legend=True, ttype='colour', fig=fig, colour=cc[i]) #, bbox=(1.05, 0.9))
#     plt.show()

    
    atd = p.attdt()
    for i in range(len(files)):
        atd = p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim2, scale2, limited, dirr, files[i], atd=atd, log=False, overlay=True, labels=[labs[i]], legend=True, ttype='return', fig=fig, colour=cc[i]) #, bbox=(1.05, 0.9))
        print(atd.keys())
    
    fig = plt.figure(figsize=(10, 2))
    plt.title(title + ' histogram')
    p.histernator('txTime', 'energy', atd, bins=80, fig=fig)
    plt.show()

#     fig = plt.figure(figsize=(6, 4))
#     for i in range(len(files)):
#         p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim3, scale3, limited, dirr, files[i], log=False, overlay=True, labels=[labs[i]], legend=True, type='colour', fig=fig, colour=cc[i]) #, bbox=(1.05, 0.9))
#     print(plt.xticks())
#     plt.show()
# Out:
# custom jupyter @DanielRobinson
# ########################################################################################################################
# logs/zte_mtn/rf_shield/ublox/release/release0/*
# logs/zte_mtn/rf_shield/ublox/release/release1/*
# logs/zte_mtn/rf_shield/ublox/release/release16/*
# points 139
# logs/zte_mtn/rf_shield/ublox/release/release64/*
# logs/zte_mtn/rf_shield/ublox/release/release128/*
# points 87
# logs/zte_mtn/rf_shield/ublox/release/release256/*
# logs/zte_mtn/rf_shield/ublox/release/release512/*
# points 86
# logs/zte_mtn/rf_shield/ublox/echo/deregister/*
# logs/zte_mtn/rf_shield/ublox/echo/e/*
# logs/zte_mtn/rf_shield/ublox/echo/echo/*
# logs/zte_mtn/rf_shield/ublox/echo/register/*
# points 96
# logs/zte_mtn/rf_shield/ublox/cops/delay/*
# logs/zte_mtn/rf_shield/ublox/cops/deregister/*
# logs/zte_mtn/rf_shield/ublox/cops/release/*
# logs/zte_mtn/rf_shield/ublox/cops/tensec/*
# points 67
# logs/zte_mtn/rf_shield/ublox/drx/cap/*
# points 132
# logs/zte_mtn/rf_shield/ublox/ptau/capture/*
# points 63
# logs/zte_mtn/rf_shield/ublox/release/release0/*
# logs/zte_mtn/rf_shield/ublox/release/release1/*
# logs/zte_mtn/rf_shield/ublox/release/release16/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/zte_mtn/rf_shield/ublox/release/release64/*
# logs/zte_mtn/rf_shield/ublox/release/release128/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/zte_mtn/rf_shield/ublox/release/release256/*
# logs/zte_mtn/rf_shield/ublox/release/release512/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/zte_mtn/rf_shield/ublox/echo/deregister/*
# logs/zte_mtn/rf_shield/ublox/echo/e/*
# logs/zte_mtn/rf_shield/ublox/echo/echo/*
# logs/zte_mtn/rf_shield/ublox/echo/register/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/zte_mtn/rf_shield/ublox/cops/delay/*
# logs/zte_mtn/rf_shield/ublox/cops/deregister/*
# logs/zte_mtn/rf_shield/ublox/cops/release/*
# logs/zte_mtn/rf_shield/ublox/cops/tensec/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/zte_mtn/rf_shield/ublox/drx/cap/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/zte_mtn/rf_shield/ublox/ptau/capture/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# KeyError, IndexError 'txTime'
# KeyError, IndexError 'txTime'
# KeyError, IndexError 'txTime'
# bins 80
# hist points 61
# hist points 0
# hist points 0
# hist points 0
# hist points 199
# ########################################################################################################################
# logs/zte_mtn/rf_shield/quectel/release/release0/*
# logs/zte_mtn/rf_shield/quectel/release/release1/*
# logs/zte_mtn/rf_shield/quectel/release/release16/*
# points 50
# logs/zte_mtn/rf_shield/quectel/release/release64/*
# logs/zte_mtn/rf_shield/quectel/release/release128/*
# points 50
# logs/zte_mtn/rf_shield/quectel/release/release256/*
# logs/zte_mtn/rf_shield/quectel/release/release512/*
# points 50
# logs/zte_mtn/rf_shield/quectel/echo/deregister/*
# logs/zte_mtn/rf_shield/quectel/echo/e/*
# logs/zte_mtn/rf_shield/quectel/echo/echo/*
# logs/zte_mtn/rf_shield/quectel/echo/register/*
# points 93
# logs/zte_mtn/rf_shield/quectel/cops/delay/*
# logs/zte_mtn/rf_shield/quectel/cops/deregister/*
# logs/zte_mtn/rf_shield/quectel/cops/release/*
# logs/zte_mtn/rf_shield/quectel/cops/tensec/*
# points 95
# logs/zte_mtn/rf_shield/quectel/drx/cap/*
# points 85
# logs/zte_mtn/rf_shield/quectel/ptau/capture/*
# points 70
# logs/zte_mtn/rf_shield/quectel/release/release0/*
# logs/zte_mtn/rf_shield/quectel/release/release1/*
# logs/zte_mtn/rf_shield/quectel/release/release16/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/zte_mtn/rf_shield/quectel/release/release64/*
# logs/zte_mtn/rf_shield/quectel/release/release128/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/zte_mtn/rf_shield/quectel/release/release256/*
# logs/zte_mtn/rf_shield/quectel/release/release512/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/zte_mtn/rf_shield/quectel/echo/deregister/*
# logs/zte_mtn/rf_shield/quectel/echo/e/*
# logs/zte_mtn/rf_shield/quectel/echo/echo/*
# logs/zte_mtn/rf_shield/quectel/echo/register/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/zte_mtn/rf_shield/quectel/cops/delay/*
# logs/zte_mtn/rf_shield/quectel/cops/deregister/*
# logs/zte_mtn/rf_shield/quectel/cops/release/*
# logs/zte_mtn/rf_shield/quectel/cops/tensec/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/zte_mtn/rf_shield/quectel/drx/cap/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/zte_mtn/rf_shield/quectel/ptau/capture/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# bins 80
# hist points 113
# hist points 72
# hist points 89
# hist points 79
# hist points 140
# ########################################################################################################################
# logs/nokia_vodacom/centurycity/ublox/release/release0/*
# logs/nokia_vodacom/centurycity/ublox/release/release1/*
# logs/nokia_vodacom/centurycity/ublox/release/release16/*
# points 20
# logs/nokia_vodacom/centurycity/ublox/release/release64/*
# logs/nokia_vodacom/centurycity/ublox/release/release128/*
# KeyError, IndexError 'ECL'
# points 8
# logs/nokia_vodacom/centurycity/ublox/release/release256/*
# logs/nokia_vodacom/centurycity/ublox/release/release512/*
# KeyError, IndexError 'ECL'
# points 12
# logs/nokia_vodacom/centurycity/ublox/echo/deregister/*
# logs/nokia_vodacom/centurycity/ublox/echo/e/*
# logs/nokia_vodacom/centurycity/ublox/echo/echo/*
# logs/nokia_vodacom/centurycity/ublox/echo/register/*
# points 30
# logs/nokia_vodacom/centurycity/ublox/cops/delay/*
# logs/nokia_vodacom/centurycity/ublox/cops/deregister/*
# logs/nokia_vodacom/centurycity/ublox/cops/release/*
# logs/nokia_vodacom/centurycity/ublox/cops/tensec/*
# points 2
# logs/nokia_vodacom/centurycity/ublox/drx/cap/*
# points 84
# logs/nokia_vodacom/centurycity/ublox/ptau/capture/*
# points 32
# logs/nokia_vodacom/centurycity/ublox/release/release0/*
# logs/nokia_vodacom/centurycity/ublox/release/release1/*
# logs/nokia_vodacom/centurycity/ublox/release/release16/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/nokia_vodacom/centurycity/ublox/release/release64/*
# logs/nokia_vodacom/centurycity/ublox/release/release128/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/nokia_vodacom/centurycity/ublox/release/release256/*
# logs/nokia_vodacom/centurycity/ublox/release/release512/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/nokia_vodacom/centurycity/ublox/echo/deregister/*
# logs/nokia_vodacom/centurycity/ublox/echo/e/*
# logs/nokia_vodacom/centurycity/ublox/echo/echo/*
# logs/nokia_vodacom/centurycity/ublox/echo/register/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/nokia_vodacom/centurycity/ublox/cops/delay/*
# logs/nokia_vodacom/centurycity/ublox/cops/deregister/*
# logs/nokia_vodacom/centurycity/ublox/cops/release/*
# logs/nokia_vodacom/centurycity/ublox/cops/tensec/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/nokia_vodacom/centurycity/ublox/drx/cap/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/nokia_vodacom/centurycity/ublox/ptau/capture/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# KeyError, IndexError 'txTime'
# KeyError, IndexError 'txTime'
# KeyError, IndexError 'txTime'
# bins 80
# hist points 23
# hist points 0
# hist points 0
# hist points 0
# hist points 84
# ########################################################################################################################
# logs/nokia_vodacom/centurycity/quectel/release/release0/*
# logs/nokia_vodacom/centurycity/quectel/release/release1/*
# logs/nokia_vodacom/centurycity/quectel/release/release16/*
# points 33
# logs/nokia_vodacom/centurycity/quectel/release/release64/*
# logs/nokia_vodacom/centurycity/quectel/release/release128/*
# points 21
# logs/nokia_vodacom/centurycity/quectel/release/release256/*
# logs/nokia_vodacom/centurycity/quectel/release/release512/*
# points 19
# logs/nokia_vodacom/centurycity/quectel/echo/deregister/*
# logs/nokia_vodacom/centurycity/quectel/echo/e/*
# logs/nokia_vodacom/centurycity/quectel/echo/echo/*
# logs/nokia_vodacom/centurycity/quectel/echo/register/*
# points 41
# logs/nokia_vodacom/centurycity/quectel/cops/delay/*
# logs/nokia_vodacom/centurycity/quectel/cops/deregister/*
# logs/nokia_vodacom/centurycity/quectel/cops/release/*
# logs/nokia_vodacom/centurycity/quectel/cops/tensec/*
# KeyError, IndexError 'ECL'
# points 19
# logs/nokia_vodacom/centurycity/quectel/drx/cap/*
# points 208
# logs/nokia_vodacom/centurycity/quectel/ptau/capture/*
# points 44
# logs/nokia_vodacom/centurycity/quectel/release/release0/*
# logs/nokia_vodacom/centurycity/quectel/release/release1/*
# logs/nokia_vodacom/centurycity/quectel/release/release16/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/nokia_vodacom/centurycity/quectel/release/release64/*
# logs/nokia_vodacom/centurycity/quectel/release/release128/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/nokia_vodacom/centurycity/quectel/release/release256/*
# logs/nokia_vodacom/centurycity/quectel/release/release512/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/nokia_vodacom/centurycity/quectel/echo/deregister/*
# logs/nokia_vodacom/centurycity/quectel/echo/e/*
# logs/nokia_vodacom/centurycity/quectel/echo/echo/*
# logs/nokia_vodacom/centurycity/quectel/echo/register/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/nokia_vodacom/centurycity/quectel/cops/delay/*
# logs/nokia_vodacom/centurycity/quectel/cops/deregister/*
# logs/nokia_vodacom/centurycity/quectel/cops/release/*
# logs/nokia_vodacom/centurycity/quectel/cops/tensec/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/nokia_vodacom/centurycity/quectel/drx/cap/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# logs/nokia_vodacom/centurycity/quectel/ptau/capture/*
# dict_keys(['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'])
# bins 80
# hist points 190
# hist points 39
# hist points 52
# hist points 50
# hist points 52
