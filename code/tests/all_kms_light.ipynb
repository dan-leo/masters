# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import pandas as pd
import seaborn as sns
import plotter as p
import jupyter as j
import plotter3 as p3
import importlib
importlib.reload(p)
importlib.reload(j)
importlib.reload(p3)

dirrs = ['logs/zte_mtn/rf_shield/ublox/', 'logs/zte_mtn/rf_shield/quectel/', 'logs/nokia_vodacom/centurycity/ublox/', 'logs/nokia_vodacom/centurycity/quectel/']
# Out:
# custom jupyter @DanielRobinson

# %%
def mdb(mean=True):
    importlib.reload(p)
    importlib.reload(j)
    files = [['release/release0/*', 'release/release1/*','release/release16/*'],['release/release64/*','release/release128/*'],['release/release256/*','release/release512/*']]
    files.append(['echo/deregister/*', 'echo/e/*', 'echo/echo/*', 'echo/register/*'])
    files.append(['cops/delay/*', 'cops/deregister/*', 'cops/release/*'])#, 'cops/tensec/*'])
    files.append(['drx/cap/*'])
    files.append(['ptau/capture/*'])
    dirrs = ['logs/zte_mtn/rf_shield/quectel/', 'logs/zte_mtn/rf_shield/ublox/','logs/nokia_vodacom/centurycity/quectel/', 'logs/nokia_vodacom/centurycity/ublox/']
    # atd = p.attdt()
    mdb = []
    for f in files:
        atd = p.scatternuator('energy_snr_zte_log' + 'ky', 'kx', 'ky', 'thresh', [None]*4, 'scale', 'limited', dirrs, f, mean=mean, ttype='return')
        mdb.append(atd)
    return mdb

def db():
    return mdb(False)

# %%
# plt.style.use('default')

# %%
plt.style.available?
# Out:
# Type:        list
# String form: ['Solarize_Light2', '_classic_test', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeigh <...> -talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'tableau-colorblind10']
# Length:      26
# Docstring:
# list() -> new empty list
# list(iterable) -> new list initialized from iterable's items

# %%
# mcount = {}
# acount = {}
# kcount = {}

# %%
def plot(*args, **kwargs):
    importlib.reload(p3)
    K = kwargs.pop('K') if 'K' in kwargs else None
#     p3.plot(mdb(), *args, **kwargs, folder='plotter3')
#     mcount[args[1]+' vs '+args[0]] = p3.hist()
#     p3.plot(database, *args, **kwargs, folder='plottera')
#     acount[args[1]+' vs '+args[0]] = p3.hist()
    p3.plot(db(), *args, **kwargs, K=K if K else 3, folder='plotterk')
    kcount[args[1]+' vs '+args[0]] = p3.hist()

# %%
mcount, acount, kcount
# Out:
# ({'txTime vs Signal power': (126, 10),
#   'txTimeNW vs Signal power': (91, 5),
#   'rxTimeNW vs Signal power': (105, 13),
#   'energy vs Signal power': (127, 9),
#   'energy vs Total power': (127, 9),
#   'maxCurrent vs Signal power': (136, 0),
#   'TX power vs Signal power': (135, 0),
#   'TX power vs Total power': (135, 0),
#   'energy vs txTime': (125, 2),
#   'Total power vs Signal power': (136, 0),
#   'SNR vs Signal power': (136, 0),
#   'RSRQ vs Signal power': (136, 0),
#   'txBytes vs Signal power': (77, 16),
#   'rxBytes vs Signal power': (87, 4),
#   'Total ACK NACK RX vs Signal power': (61, 75),
#   'Cell ID vs Signal power': (136, 0),
#   'ECL vs Signal power': (136, 0),
#   'EARFCN vs Signal power': (136, 0),
#   'PCI vs Signal power': (75, 61),
#   'Current Allocated vs Signal power': (136, 0),
#   'Total Free vs Signal power': (136, 0),
#   'Max Free vs Signal power': (136, 0),
#   'Num Allocs vs Signal power': (136, 0),
#   'Num Frees vs Signal power': (136, 0)},
# ...

# %% [markdown]
# # #Latency

# %%
plot('SNR', 'txTime', 'SNR (dB)', 'Latency (s)', scale=[1,1000], invert=[False, True], K=5)
# Out:
# custom jupyter @DanielRobinson
# 7 4 5
# ky txTime 526 + 51 = 577

# %%
plot('Signal power', 'txTime', 'RSRP (dBm)', 'Latency (s)', scale=[10,1000], invert=[False, True])
# Out:
# custom jupyter @DanielRobinson
# 7 4 5
# ky txTime 342 + 42 = 384

# %%
plot('Signal power', 'txTimeNW', 'RSRP (dBm)', 'Transmit Latency (s)', scale=[10,1000], invert=[False, True])
# Out:
# custom jupyter @DanielRobinson
# 7 4 5
# ky txTimeNW 225 + 11 = 236

# %%
plot('Signal power', 'rxTimeNW', 'RSRP (dBm)', 'Receive Latency (s)', scale=[10,1000], invert=[False, True])
# Out:
# custom jupyter @DanielRobinson
# 7 4 5
# ky rxTimeNW 283 + 36 = 319

# %% [markdown]
# # #Power saving

# %%
plot('Signal power', 'energy', 'RSRP (dBm)', 'Energy (J)', [10,1000], [False, True])
# Out:
# custom jupyter @DanielRobinson
# 7 4 5
# ky energy 340 + 46 = 386

# %%
plot('Total power', 'energy', 'RSSI (dBm)', 'Energy (J)', scale=[10,1000], invert=[False, True])
# Out:
# custom jupyter @DanielRobinson
# 7 4 5
# ky energy 340 + 46 = 386

# %%
plot('Signal power', 'maxCurrent', 'RSRP (dBm)', 'Max current (mA)', scale=[10,1], invert=[False, True], loc='lower left', bbox=None)
# Out:
# custom jupyter @DanielRobinson
# 7 4 5
# ky maxCurrent 372 + 0 = 372

# %%
plot('Signal power', 'TX power', 'RSRP (dBm)', 'Transmit power (dBm)', scale=[10,10], invert=[False, True], loc='lower left', bbox=None)
# Out:
# custom jupyter @DanielRobinson
# 7 4 5
# ky TX power 204 + 0 = 204

# %%
plot('Total power', 'TX power', 'RSSI (dBm)', 'Transmit power (dBm)', scale=[10,10], invert=[False, True], loc='lower left', bbox=None)
# Out:
# custom jupyter @DanielRobinson
# 7 4 5
# ky TX power 204 + 0 = 204

# %%
plot('txTime', 'energy', 'Latency (s)', 'Energy (J)', [1000,1000], [True, False])
# Out:
# custom jupyter @DanielRobinson
# 7 4 5
# ky energy 322 + 47 = 369

# %% [markdown]
# # #RF Receive metrics

# %%
plot('Signal power', 'Total power', scale=[10,10], invert=[False, True], loc='bottom right')

# %%
plot('Signal power', 'SNR', scale=[10,10], invert=[False, True])
# Out:
# custom jupyter @DanielRobinson
# 7 4 5
# ky SNR 389 + 0 = 389

# %%
plot('Signal power', 'RSRQ', scale=[10,1], invert=[False, True])
# Out:
# custom jupyter @DanielRobinson
# 7 4 5
# ky RSRQ 386 + 0 = 386

# %% [markdown]
# # #Packet metrics

# %%
plot('Signal power', 'txBytes', 'RSRP (dBm)', 'TX Bytes (B)', scale=[10,1], invert=[False, True], K=3)
# Out:
# custom jupyter @DanielRobinson
# 7 4 5
# ky txBytes 174 + 37 = 211

# %%
plot('Signal power', 'rxBytes', 'RSRP (dBm)', 'RX Bytes (B)', scale=[10,1], invert=[False, True], K=3)
# Out:
# custom jupyter @DanielRobinson
# 7 4 5
# ky rxBytes 166 + 12 = 178

# %%
plot('Signal power', 'Total ACK NACK RX', 'RSRP (dBm)', 'ACK/NACK RX Packets', scale=[10,1], invert=[False, True], K=3)
# Out:
# custom jupyter @DanielRobinson
# 7 4 5
# ky Total ACK NACK RX 83 + 0 = 83

# %% [markdown]
# # #Network metrics

# %%
plot('Signal power', 'Cell ID', 'RSRP (dBm)', 'Cell ID', scale=[10,1], invert=[False, True], K=3)
# Out:
# custom jupyter @DanielRobinson
# 7 4 5
# ky Cell ID 173 + 0 = 173

# %%
plot('Signal power', 'ECL', 'RSRP (dBm)', 'ECL', scale=[10,1], invert=[False, True], K=4)
# Out:
# custom jupyter @DanielRobinson
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-134-1546241f93fb> in <module>
# ----> 1 plot('Signal power', 'ECL', 'RSRP (dBm)', 'ECL', scale=[10,1], invert=[False, True], K=4)
#
# <ipython-input-119-f7e8344cda50> in plot(*args, **kwargs)
#       6 #     p3.plot(database, *args, **kwargs, folder='plottera')
#       7 #     acount[args[1]+' vs '+args[0]] = p3.hist()
# ----> 8     p3.plot(db(), *args, **kwargs, K=K if K else 3, folder='plotterk')
#       9     kcount[args[1]+' vs '+args[0]] = p3.hist()
#
# /mnt/c/GIT/masters/code/tests/plotter3.py in plot(mdb, kx, ky, xlabel, ylabel, scale, invert, colour, folder, K, loc)
#      87                                 atd[kx] = np.array(atd[kx])[re]
#      88                                 atd[ky] = np.array(atd[ky])[re]
# ...

# %%
plot('Signal power', 'EARFCN', 'RSRP (dBm)', 'EARFCN', scale=[10,1], invert=[False, True])

# %%
plot('Signal power', 'PCI', 'RSRP (dBm)', 'PCI', scale=[10,1], invert=[False, True], K=3)

# %% [markdown]
# # #Memory

# %%
plot('Signal power', 'Current Allocated', 'RSRP (dBm)', 'Currently allocated memory', scale=[10,1], invert=[False, True])

# %%
plot('Signal power', 'Total Free', 'RSRP (dBm)', 'Total free memory', scale=[10,1], invert=[False, True])

# %%
plot('Signal power', 'Max Free', 'RSRP (dBm)', 'Max free memory', scale=[10,1], invert=[False, True])

# %%
plot('Signal power', 'Num Allocs', 'RSRP (dBm)', 'Num Allocs memory', scale=[10,1], invert=[False, True], K=3)

# %%
plot('Signal power', 'Num Frees', 'RSRP (dBm)', 'Num Frees memory', scale=[10,1], invert=[False, True], K=3)

# %%
import time
time.time()
# Out:
# 1567503070.8472989

# %%
1567502344.4278362 - time.time()
# Out:
# -726.4489011764526

# %%
# import time
# time.time()
# 1567497531.5306807
# Out:
# 1567497531.5306807

# %%
import time
time.time()
# Out:
# 1567927145.159122

# %%
1567926708.911656 - time.time()
# Out:
# -436.29223346710205

# %%
436/60
# Out:
# 7.266666666666667

# %%
# Sunday 8 September 2019
time.time() - 1567951464.4140053
