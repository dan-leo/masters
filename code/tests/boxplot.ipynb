# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)

# fake up some data
spread = np.random.rand(50) * 100
center = np.ones(25) * 50
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
data = np.concatenate((spread, center, flier_high, flier_low))

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f74129fba20>,
#   <matplotlib.lines.Line2D at 0x7f74129fbdd8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f7412a09160>,
#   <matplotlib.lines.Line2D at 0x7f7412a094a8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f74129fb8d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f7412a097f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f7412a09b38>],
#  'means': []}

# %%
fig2, ax2 = plt.subplots()
ax2.set_title('Notched boxes')
ax2.boxplot(data, notch=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f74129dbc18>,
#   <matplotlib.lines.Line2D at 0x7f74129dbef0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f7412968278>,
#   <matplotlib.lines.Line2D at 0x7f74129685c0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f74129db908>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f7412968908>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f7412968c50>],
#  'means': []}

# %%
import matplotlib.pyplot as plt

data = {'apples': 10, 'oranges': 15, 'lemons': 5, 'limes': 20}
names = list(data.keys())
values = list(data.values())

fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True)
axs[0].bar(names, values)
axs[1].scatter(names, values)
axs[2].plot(names, values)
fig.suptitle('Categorical Plotting')
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')

# %%
axs
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f7412d44278>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7412ce3748>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7412d13ba8>],
#       dtype=object)

# %%
fig2, ax2 = plt.subplots()
ax2.set_title('Notched boxes')
ax2.boxplot(data, notch=True)
locs = ax2.get_yticks()
ax2.set_yticklabels([])
# plt.gca().axes.get_yaxis().set_visible(False)
# Out:
# []

# %%
ax2.set_yticks?
# Out:
# Signature: ax2.set_yticks(ticks, minor=False)
# Docstring:
# Set the y ticks with list of *ticks*
#
# Parameters
# ----------
# ticks : list
#     List of y-axis tick locations
#
# minor : bool, optional
#     If ``False`` sets major ticks, if ``True`` sets minor ticks.
#     Default is ``False``.
# File:      ~/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py
# Type:      method

# %%
import matplotlib.pyplot as plt
x = range(10)
y = range(10)
plt.plot(x,y)
plt.xticks(x," ")
plt.show()
