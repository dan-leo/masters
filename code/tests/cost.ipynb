# %%
import numpy as np
import matplotlib.pyplot as plt
import jupyter as j
import importlib

def compare(*args, **kwargs):
    importlib.reload(j)
    j.compare(*args, **kwargs)
    
def jthresh(*args, **kwargs):
#     importlib.reload(j)
    j.thresh(*args, **kwargs)
# Out:
# custom jupyter @DanielRobinson

# %%
files = []
files.append(['release/release1/*','release/release16/*','release/release64/*','release/release128/*','release/release256/*','release/release512/*', 'release/release0/*'])
# files.append(['echo/deregister/*', 'echo/e/*', 'echo/echo/*', 'echo/register/*'])
# files.append(['cops/delay/*', 'cops/deregister/*', 'cops/release/*', 'cops/tensec/*'])
files.append(['drx/cap/*'])
files.append(['ptau/capture/*'])
files = sum(files, [])
print(files)
# Out:
# ['release/release1/*', 'release/release16/*', 'release/release64/*', 'release/release128/*', 'release/release256/*', 'release/release512/*', 'release/release0/*', 'drx/cap/*', 'ptau/capture/*']

# %%
k = [1,2]
k[[a in [2,3,4] for a in k].index(True)]
# Out:
# 2

# %%
compare(files, jthresh, 'UDP packet TX bytes vs Received Signal Power', 'TX bytes', 'RSRP (dBm)', 'Total TX bytes', 'Signal power', 1, 10, overlays=['ublox', 'quectel'], graphs=['zte', 'nokia'])
compare(files, jthresh, 'UDP packet RX bytes vs Received Signal Power', 'RX bytes', 'RSRP (dBm)', 'Total RX bytes', 'Signal power', 1, 10, overlays=['ublox', 'quectel'], graphs=['zte', 'nokia'])
# Out:
# custom jupyter @DanielRobinson
# custom jupyter @DanielRobinson
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-24cfdbd1add7> in <module>
# ----> 1 compare(files, jthresh, 'UDP packet TX bytes vs Received Signal Power', 'TX bytes', 'RSRP (dBm)', 'Total TX bytes', 'Signal power', 1, 10, overlays=['ublox', 'quectel'], graphs=['zte', 'nokia'])
#       2 compare(files, jthresh, 'UDP packet RX bytes vs Received Signal Power', 'RX bytes', 'RSRP (dBm)', 'Total RX bytes', 'Signal power', 1, 10, overlays=['ublox', 'quectel'], graphs=['zte', 'nokia'])
#
# <ipython-input-1-cb562f2791ab> in compare(*args, **kwargs)
#       6 def compare(*args, **kwargs):
#       7     importlib.reload(j)
# ----> 8     j.compare(*args, **kwargs)
#       9
#      10 def jthresh(*args, **kwargs):
#
# C:\GIT\masters\code\tests\jupyter.py in compare(files, thresh, text, ylabel, xlabel, ky, kx, ry, rx, overlays, graphs, split, hist, bins, log, weighted)
#     107                     pcolours.append(colours[nwi][uei])
#     108                 # print(i, s, j, dirr, nwi, uei)
# --> 109                 hy, ly = plot(ax[0], ax[1], kx, ky, rx, ry, files, colours[nwi][uei], alpha, (i, split), hist, thresh, [[s, len(graphs)], [j, len(overlays)]], bins, log, dev[uei])
#     110                 if hist and str(type(hy)) != "<class 'NoneType'>":
#     111                     lens.append(len(hy))
#
# C:\GIT\masters\code\tests\jupyter.py in plot(ax1, ax2, x, y, xr, yr, files, colour, alpha, split, hist, thresh, indexes, bins, log, overlay)
#     186         # print('zu_mg', zu_mg)
#     187         if zu_mg:
# --> 188             p, q, limits = dict_filt(zu_mg, x, y, split, thresh)
#     189             # print('p, q', p, q, 'limits', limits)
#     190             try:
#
# C:\GIT\masters\code\tests\jupyter.py in dict_filt(dc, x, y, split, thresh)
#     280             # ky = [y, y[1:-1]]
#     281             # ky = ky[[a in dc.keys() for a in ky].index(True)]
# --> 282             t, limitx = thresh(dc, x, split)
#     283             t2, limity = thresh(dc, y, split)
#     284             if len(t):
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
compare(files, jthresh, 'UDP packet TX bytes vs Received Signal Power', 'TX bytes', 'RSRP (dBm)', 'txBytes', 'Signal power', 1, 10, split=3, overlays=['ublox', 'quectel'], graphs=['zte', 'nokia'])
# Out:
# custom jupyter @DanielRobinson
# custom jupyter @DanielRobinson
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-38c11c3a241b> in <module>
# ----> 1 compare(files, jthresh, 'UDP packet TX bytes vs Received Signal Power', 'TX bytes', 'RSRP (dBm)', 'txBytes', 'Signal power', 1, 10, split=3, overlays=['ublox', 'quectel'], graphs=['zte', 'nokia'])
#
# <ipython-input-114-cb562f2791ab> in compare(*args, **kwargs)
#       6 def compare(*args, **kwargs):
#       7     importlib.reload(j)
# ----> 8     j.compare(*args, **kwargs)
#       9
#      10 def jthresh(*args, **kwargs):
#
# C:\GIT\masters\code\tests\jupyter.py in compare(files, thresh, text, ylabel, xlabel, ky, kx, ry, rx, overlays, graphs, split, hist, bins, log, weighted)
#     107                     pcolours.append(colours[nwi][uei])
#     108                 # print(i, s, j, dirr, nwi, uei)
# --> 109                 hy, ly = plot(ax[0], ax[1], kx, ky, rx, ry, files, colours[nwi][uei], alpha, (i, split), hist, thresh, [[s, len(graphs)], [j, len(overlays)]], bins, log, dev[uei])
#     110                 if hist and str(type(hy)) != "<class 'NoneType'>":
#     111                     lens.append(len(hy))
#
# C:\GIT\masters\code\tests\jupyter.py in plot(ax1, ax2, x, y, xr, yr, files, colour, alpha, split, hist, thresh, indexes, bins, log, overlay)
#     186         # print('zu_mg', zu_mg)
#     187         if zu_mg:
# --> 188             p, q, limits = dict_filt(zu_mg, x, y, split, thresh)
#     189             # print('p, q', p, q, 'limits', limits)
#     190             try:
#
# C:\GIT\masters\code\tests\jupyter.py in dict_filt(dc, x, y, split, thresh)
#     280             # ky = [y, y[1:-1]]
#     281             # ky = ky[[a in dc.keys() for a in ky].index(True)]
# --> 282             t, limitx = thresh(dc, x, split)
#     283             t2, limity = thresh(dc, y, split)
#     284             if len(t):
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
compare(files, jthresh, 'UDP packet TX bytes vs Received Signal Power', 'TX bytes', 'RSRP (dBm)', 'txBytes', 'Signal power', 1, 10, split=1, hist=True, log=True, overlays=['ublox', 'quectel'], graphs=['zte', 'nokia'])
# Out:
# custom jupyter @DanielRobinson
# custom jupyter @DanielRobinson
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-119-7a5528389669> in <module>
# ----> 1 compare(files, jthresh, 'UDP packet TX bytes vs Received Signal Power', 'TX bytes', 'RSRP (dBm)', 'txBytes', 'Signal power', 1, 10, split=1, hist=True, log=True, overlays=['ublox', 'quectel'], graphs=['zte', 'nokia'])
#
# <ipython-input-114-cb562f2791ab> in compare(*args, **kwargs)
#       6 def compare(*args, **kwargs):
#       7     importlib.reload(j)
# ----> 8     j.compare(*args, **kwargs)
#       9
#      10 def jthresh(*args, **kwargs):
#
# C:\GIT\masters\code\tests\jupyter.py in compare(files, thresh, text, ylabel, xlabel, ky, kx, ry, rx, overlays, graphs, split, hist, bins, log, weighted)
#     107                     pcolours.append(colours[nwi][uei])
#     108                 # print(i, s, j, dirr, nwi, uei)
# --> 109                 hy, ly = plot(ax[0], ax[1], kx, ky, rx, ry, files, colours[nwi][uei], alpha, (i, split), hist, thresh, [[s, len(graphs)], [j, len(overlays)]], bins, log, dev[uei])
#     110                 if hist and str(type(hy)) != "<class 'NoneType'>":
#     111                     lens.append(len(hy))
#
# C:\GIT\masters\code\tests\jupyter.py in plot(ax1, ax2, x, y, xr, yr, files, colour, alpha, split, hist, thresh, indexes, bins, log, overlay)
#     186         # print('zu_mg', zu_mg)
#     187         if zu_mg:
# --> 188             p, q, limits = dict_filt(zu_mg, x, y, split, thresh)
#     189             # print('p, q', p, q, 'limits', limits)
#     190             try:
#
# C:\GIT\masters\code\tests\jupyter.py in dict_filt(dc, x, y, split, thresh)
#     280             # ky = [y, y[1:-1]]
#     281             # ky = ky[[a in dc.keys() for a in ky].index(True)]
# --> 282             t, limitx = thresh(dc, x, split)
#     283             t2, limity = thresh(dc, y, split)
#     284             if len(t):
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
compare(files, jthresh, 'UDP packet TX bytes vs Received Signal Power', 'TX bytes', 'RSRP (dBm)', 'txBytes', 'Signal power', 1, 10, split=3, hist=True, log=True, overlays=['ublox', 'quectel'], graphs=['zte', 'nokia'])

# %%
compare(files, jthresh, 'UDP packet RX bytes vs Received Signal Power', 'RX bytes', 'RSRP (dBm)', 'rxBytes', 'Signal power', 1, 10, split=3, overlays=['ublox', 'quectel'], graphs=['zte', 'nokia'])

# %%
compare(files, jthresh, 'UDP packet RX bytes vs Received Signal Power', 'RX bytes', 'RSRP (dBm)', 'rxBytes', 'Signal power', 1, 10, split=1, hist=True, log=True, overlays=['ublox', 'quectel'], graphs=['zte', 'nokia'])

# %%
compare(files, jthresh, 'UDP packet RX bytes vs Received Signal Power', 'RX bytes', 'RSRP (dBm)', 'rxBytes', 'Signal power', 1, 10, split=3, hist=True, log=True, overlays=['ublox', 'quectel'], graphs=['zte', 'nokia'])

# %%
compare(files, jthresh, 'UDP packet TX time vs Received Signal Power', 'TX time', 'RSRP (dBm)', 'TX time', 'Signal power', 1, 10)
compare(files, jthresh, 'UDP packet RX time vs Received Signal Power', 'RX time', 'RSRP (dBm)', 'RX time', 'Signal power', 1, 10)
