# %%
import numpy as np
import matplotlib.pyplot as plt
import jupyter as j
import importlib

def compare(files, thresh, text, ylabel, xlabel, ky, kx, ry, rx, overlays=['ublox', 'quectel'], graphs=['zte', 'nokia'], split=1, hist=False, bins=20, log=False):
    importlib.reload(j)
    j.compare(files, thresh, text, ylabel, xlabel, ky, kx, ry, rx, overlays, graphs, split, hist, bins, log)
    
def thresh(a, key, split):
    return j.thresh(a, key, split)
# Out:
# custom jupyter @DanielRobinson

# %%
files = []
files.append(['release/release1/*','release/release16/*','release/release64/*','release/release128/*','release/release256/*','release/release512/*', 'release/release0/*'])
files.append(['echo/deregister/*', 'echo/e/*', 'echo/echo/*', 'echo/register/*'])
files.append(['cops/delay/*', 'cops/deregister/*', 'cops/release/*', 'cops/tensec/*'])
files.append(['drx/cap/*'])
files.append(['ptau/capture/*'])
files = sum(files, [])
print(files)
# Out:
# ['release/release1/*', 'release/release16/*', 'release/release64/*', 'release/release128/*', 'release/release256/*', 'release/release512/*', 'release/release0/*', 'echo/deregister/*', 'echo/e/*', 'echo/echo/*', 'echo/register/*', 'cops/delay/*', 'cops/deregister/*', 'cops/release/*', 'cops/tensec/*', 'drx/cap/*', 'ptau/capture/*']

# %%
compare(files, thresh, 'UDP packet TX bytes vs Received Signal Power', 'TX bytes', 'RSRP (dBm)', 'Total TX bytes', 'Signal power', 1, 10)
compare(files, thresh, 'UDP packet RX bytes vs Received Signal Power', 'RX bytes', 'RSRP (dBm)', 'Total RX bytes', 'Signal power', 1, 10)
# Out:
# custom jupyter @DanielRobinson
# custom jupyter @DanielRobinson

# %%
compare(files, thresh, 'UDP packet TX bytes vs Received Signal Power', 'TX bytes', 'RSRP (dBm)', 'txBytes', 'txBytes_rsrp', 1, 10)
# Out:
# custom jupyter @DanielRobinson
# files release/release1/* dirr logs/zte_mtn/rf_shield/ublox/
# dp['txBytes'] [1958. 1873.  213.  114.  107.  114.]
# dp['txBytes'] [114. 114. 114.]
# dp['txBytes'] [220. 114. 114. 114.]
# dp['txBytes'] [114. 114. 114.]
# dp['txBytes'] [0.]
# dp['txBytes'] [   95.    95.    97. -9873.  1919.    95.   204.   128.]
# dp['txBytes'] [213. 114. 114. 114.]
# dp['txBytes'] [ 114. -451.  120.]
# dp['txBytes'] [213. 114. 137. 112.]
# dp['txBytes'] [107. 232. 127.]
# dp['txBytes'] [   204.    116.    116.     95. -21196.    250.    118.    107.   -745.
#    1513.  -1036.]
# dp['txBytes'] [128.  95. 128.]
# dp['txBytes'] []
# dp['txBytes'] []
# dp['txBytes'] []
# dp['txBytes'] []
# dp['txBytes'] []
# <class 'numpy.ndarray'>
# txBytes_rsrp
# [None, None]
# files release/release16/* dirr logs/zte_mtn/rf_shield/ublox/
# dp['txBytes'] [1965. 2421.]
# dp['txBytes'] [237. 131. 138.]
# dp['txBytes'] []
# dp['txBytes'] [138. 138. 237.]
# ...

# %%
[1] * 2
# Out:
# [1, 1]

# %%
compare(files, thresh, 'UDP packet TX time vs Received Signal Power', 'TX time', 'RSRP (dBm)', 'TX time', 'Signal power', 1, 10)
compare(files, thresh, 'UDP packet RX time vs Received Signal Power', 'RX time', 'RSRP (dBm)', 'RX time', 'Signal power', 1, 10)
# Out:
# custom jupyter @DanielRobinson
# -6013.6 126285.6
# custom jupyter @DanielRobinson
# -21094.75 465451.75
