# %%
import numpy as np
import matplotlib.pyplot as plt
import jupyter as j
import importlib
import pandas as pd
import seaborn as sns
importlib.reload(j)

import matplotlib.ticker as ticker
import glob

import plotter as p
importlib.reload(p)

dirrs = ['logs/zte_mtn/rf_shield/ublox/', 'logs/zte_mtn/rf_shield/quectel/', 'logs/nokia_vodacom/centurycity/ublox/', 'logs/nokia_vodacom/centurycity/quectel/']
# Out:
# custom jupyter @DanielRobinson

# %%
kx = 'txTime'
ky = 'energy'
limited=False
thresh = [None, 1000, None, None, ]
importlib.reload(p)
importlib.reload(j)
scales = [[1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000]]
scale2s = [[1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000]]
scale3s = [[1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000]]
plotlims = [[1,  30, 1, 40], [1,  16, 1, 30], [1,  250, 1, 400], [1,  250, 1, 400]]
plotlim2s = [[1,  10, 1, 10], [1,  10, 1, 10], [3,  50, 1, 100], [3,  50, 1, 100]]
plotlim3s = [[1,  3, 200, 2000], [0.7,  3, 100, 2000], [3,  10, 1, 20], [3,  10, 1, 20]]

for dirr, scale, scale2, scale3, plotlim, plotlim2, plotlim3 in zip(dirrs, scales, scale2s, scale3s, plotlims, plotlim2s, plotlim3s):
    print('########################################################################################################################')
    dirr = [dirr]
    dgrams = [1, 16, 64, 128, 256, 512]
    cc = ['tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:blue', 'tab:brown']
    fig = plt.figure(figsize=(6, 4))
    # files = [['release/release0/*', 'release/release1/*','release/release16/*'],['release/release64/*','release/release128/*'],['release/release256/*','release/release512/*']]
    # files.append(['echo/deregister/*', 'echo/e/*', 'echo/echo/*', 'echo/register/*'])
    # files.append(['cops/delay/*', 'cops/deregister/*', 'cops/release/*', 'cops/tensec/*'])
    # labs = ['1-16 B', '64-128 B', '256-512 B', 'echo', 'cops']
    files = [['drx/cap/*']]
    labs = ['drx']
    # files = ['ptau/capture/*']
    for i in range(len(files)):
        p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim, scale, limited, dirr, files[i], log=False, overlay=True, labels=[labs[i]], legend=True, ttype='colour', fig=fig, colour=cc[i]) #, bbox=(1.05, 0.9))
    print(plt.xticks())
    plt.show()

    # fig = plt.figure(figsize=(6, 4))
    atd = p.attdt()
    for i in range(len(files)):
        atd = p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim2, scale2, limited, dirr, files[i], atd=atd, log=False, overlay=True, labels=[labs[i]], legend=True, ttype='return', fig=fig, colour=cc[i]) #, bbox=(1.05, 0.9))
    
    fig = plt.figure(figsize=(5, 2))
    p.histernator('txTime', 'energy', atd, thresh, bins=40, fig=fig)
    plt.show()

#     fig = plt.figure(figsize=(6, 4))
#     for i in range(len(files)):
#         p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim3, scale3, limited, dirr, files[i], log=False, overlay=True, labels=[labs[i]], legend=True, type='colour', fig=fig, colour=cc[i]) #, bbox=(1.05, 0.9))
#     print(plt.xticks())
#     plt.show()
# Out:
# custom jupyter @DanielRobinson
# ########################################################################################################################
# logs/zte_mtn/rf_shield/ublox/
# (array([  0., 100., 200., 300., 400., 500., 600.]), <a list of 7 Text xticklabel objects>)
# logs/zte_mtn/rf_shield/ublox/
# bins 40
# ########################################################################################################################
# logs/zte_mtn/rf_shield/quectel/
# (array([200., 250., 300., 350., 400., 450., 500.]), <a list of 7 Text xticklabel objects>)
# logs/zte_mtn/rf_shield/quectel/
# bins 40
# ########################################################################################################################
# logs/nokia_vodacom/centurycity/ublox/
# (array([300., 320., 340., 360., 380., 400., 420., 440., 460.]), <a list of 9 Text xticklabel objects>)
# logs/nokia_vodacom/centurycity/ublox/
# bins 40
# ########################################################################################################################
# logs/nokia_vodacom/centurycity/quectel/
# (array([-100.,    0.,  100.,  200.,  300.,  400.,  500.,  600.,  700.]), <a list of 9 Text xticklabel objects>)
# logs/nokia_vodacom/centurycity/quectel/
# bins 40

# %%
kx = 'txTime'
ky = 'energy'
title = 'eDRX energy vs latency'
limited=False
threshs = [[None, 1000, None, None], [None, 3000, None, None], [None, 15000, None, None], [None, 15000, None, None]]
# threshs = [[3000, None, None, None], [3000, None, None, None], [10000, None, None, None], [15000, None, None, None]]
importlib.reload(p)
importlib.reload(j)
scales = [[1, 1], [1, 1], [1000, 1000], [1000, 1000]]
scale2s = [[1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000]]
scale3s = [[1000, 1000], [1000, 1000], [1000, 1000], [1000, 1000]]
plotlims = [[1,  30, 1, 40], [1,  16, 1, 30], [1,  250, 1, 400], [1,  250, 1, 400]]
plotlim2s = [[100,  135, 2, 2.8], [1,  200, None, None], [1,  200, None, None], [1,  200, None, None]]
plotlim3s = [[1,  3, 200, 2000], [0.7,  3, 100, 2000], [3,  10, 1, 20], [3,  10, 1, 20]]

for dirr, scale, scale2, scale3, plotlim, plotlim2, plotlim3, thresh in zip(dirrs, scales, scale2s, scale3s, plotlims, plotlim2s, plotlim3s, threshs):
    print('########################################################################################################################')
    dirr = [dirr]
    dgrams = [1, 16, 64, 128, 256, 512]
    cc = ['tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:blue', 'tab:brown']
    fig = plt.figure(figsize=(5, 3))
    plt.title(title + ' plot')
    # files = [['release/release0/*', 'release/release1/*','release/release16/*'],['release/release64/*','release/release128/*'],['release/release256/*','release/release512/*']]
    # files.append(['echo/deregister/*', 'echo/e/*', 'echo/echo/*', 'echo/register/*'])
    # files.append(['cops/delay/*', 'cops/deregister/*', 'cops/release/*', 'cops/tensec/*'])
    # labs = ['1-16 B', '64-128 B', '256-512 B', 'echo', 'cops']
    files = [['drx/cap/*']]
    labs = ['drx']
#     files = [['ptau/capture/*']]
    for i in range(len(files)):
        p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim, scale, limited, dirr, files[i], scaled=True, log=False, overlay=True, labels=[labs[i]], legend=True, ttype='colour', fig=fig, colour=cc[i]) #, bbox=(1.05, 0.9))
#     print(plt.xticks())
    plt.show()
    
    fig = plt.figure(figsize=(5, 3))
    plt.title(title + ' plot')
    labs = ['drx2']
    for i in range(len(files)):
        p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim2, scale, True, dirr, files[i], log=False, overlay=True, labels=[labs[i]], legend=True, ttype='colour', fig=fig, colour=cc[i]) #, bbox=(1.05, 0.9))
    plt.show()

    
    atd = p.attdt()
    for i in range(len(files)):
        atd = p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim2, scale2, limited, dirr, files[i], atd=atd, log=False, overlay=True, labels=[labs[i]], legend=True, ttype='return', fig=fig, colour=cc[i]) #, bbox=(1.05, 0.9))
    
    fig = plt.figure(figsize=(10, 2))
    plt.title(title + ' histogram')
    p.histernator('txTime', 'energy', atd, thresh, scale, bins=80, fig=fig)
    plt.show()

#     fig = plt.figure(figsize=(6, 4))
#     for i in range(len(files)):
#         p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim3, scale3, limited, dirr, files[i], log=False, overlay=True, labels=[labs[i]], legend=True, type='colour', fig=fig, colour=cc[i]) #, bbox=(1.05, 0.9))
#     print(plt.xticks())
#     plt.show()
# Out:
# custom jupyter @DanielRobinson
# ########################################################################################################################
# logs/zte_mtn/rf_shield/ublox/
# logs/zte_mtn/rf_shield/ublox/
# logs/zte_mtn/rf_shield/ublox/
# bins 80
# ########################################################################################################################
# logs/zte_mtn/rf_shield/quectel/
# logs/zte_mtn/rf_shield/quectel/
# logs/zte_mtn/rf_shield/quectel/
# bins 80
# ########################################################################################################################
# logs/nokia_vodacom/centurycity/ublox/
# logs/nokia_vodacom/centurycity/ublox/
# logs/nokia_vodacom/centurycity/ublox/
# bins 80
# ########################################################################################################################
# logs/nokia_vodacom/centurycity/quectel/
# logs/nokia_vodacom/centurycity/quectel/
# logs/nokia_vodacom/centurycity/quectel/
# bins 80
