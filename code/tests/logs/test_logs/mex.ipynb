936.0,11936.0,11929.0,11932.0,11930.0,11927.5,11934.5,11926.0,11939.0,11944.5,11953.0,11946.0,11948.5,11950.5,11949.0,11956.0,11944.5,11954.5,11953.0,11953.0,11969.0,11950.5,11910.0,11905.0,11910.5,11912.0,11869.5,11897.5,11890.5,11892.0,11911.5,11917.5,11919.0,11933.0,11930.5,11914.5,11920.5,11886.5,11879.5,11880.5,11869.5,11875.0,11875.0,11866.5,11879.5,11879.5,11879.5,11882.0,11890.5,11886.5,11872.5,11936.0,11934.5,11927.5,11912.0,11961.5,11929.0,11884.5,11892.0,11848.5,11875.0,11897.5,11799.5,]
plt.plot(c[::-1])

# %%
i = [-1000,1000,-1000,1000,1000,-1000,2000,-2000,1000,-2000,2000,-2000,2000,-2000,2000,-2000,2000,-2000,2000,-2000,2000,2000,-2000,-2000,2000,-2000,2000,-2000,2000,-2000,2000,-2000,2000,-2000,2000,-2000,2000,-2000,2000,-2000,2000,-2000,1000,1000,-1000,1000,-1000,1000,-1000,1000,-1000,1000,-1000,1000,-1000,1000,-1000,-1000,1000,-1000,1000,1000,-1000,1000,-1000,1000,-1000,1000,-1000,1000,-1000,1000,-1000,1000,-1000,1000,-1000,1000,-1000,1000,-1000,1000,-1000,1000,-1000,1000,-1000,1000,-1000,1000,-1000,1000,-1000,1000,-1000,1000,-1500,-500,500,500,300,]
i = np.array(i[::-1])

# %%
t = np.arange(0, len(c), 1)
xy = np.array([t, c[::-1]])
buy = []
sell = []
# for p in xy.T:
#     print(p)
for s, p in zip(i > 0, xy.T):
    if s:
        buy.append(p)
    else:
        sell.append(p)
buy = np.array(buy).T
sell = np.array(sell).T
plt.figure(figsize=(4,8))
plt.plot(buy[0], buy[1], 'g*', sell[0], sell[1], 'r*', xy[0], xy[1], 'b-')

# %%
np.set_printoptions(precision=2, suppress=True)
profit = []
c = c[::-1]
# d = i / c
# d.insert([0]) - [0].append(i / c)
e = np.append(i / c, [0]) - np.append([0], i / c)
sum(i/c)
sum(e)
# e.sort()
e
d = i/c
# d.sort()
d
# for i in d
# e
# Out:
# array([ 0.03,  0.04,  0.04, -0.04, -0.13,  0.08, -0.08,  0.08, -0.08,
#         0.08, -0.08,  0.08, -0.08,  0.08, -0.08,  0.08, -0.08,  0.08,
#        -0.08,  0.08, -0.08,  0.08, -0.08,  0.08, -0.08,  0.08, -0.08,
#         0.08, -0.08,  0.08, -0.08,  0.08, -0.08,  0.08, -0.08,  0.08,
#        -0.08,  0.08, -0.08,  0.08,  0.08, -0.08,  0.08, -0.08, -0.08,
#         0.08, -0.08,  0.08, -0.08,  0.08, -0.08,  0.08, -0.08,  0.08,
#        -0.08,  0.08, -0.08,  0.08,  0.08, -0.17,  0.17, -0.17,  0.17,
#        -0.17,  0.17, -0.17,  0.17, -0.17,  0.17, -0.17,  0.17, -0.17,
#         0.17, -0.17,  0.17, -0.17,  0.17, -0.17, -0.17,  0.17,  0.17,
#        -0.17,  0.17, -0.17,  0.17, -0.17,  0.17, -0.17,  0.17, -0.17,
#         0.17, -0.17,  0.08, -0.17,  0.17, -0.08,  0.08,  0.08, -0.08,
#         0.08, -0.08])

# %%
sum(np.abs(i)/c)*0.0075
# Out:
# 0.0843457368434402

# %%
(1000/11800 * 12000 - 1000) * 0.9925 * 15
# Out:
# 252.33050847457613

# %%
1016/11800 - 1000/11800
# Out:
# 0.0013559322033898369
