# %%
import numpy as np
import matplotlib.pyplot as plt
import jupyter as j
import importlib

def compare(files, thresh, text, ylabel, xlabel, ky, kx, ry, rx, overlays=['ublox', 'quectel'], graphs=['zte', 'nokia'], split=1, hist=False, bins=20, log=False):
    importlib.reload(j)
    j.compare(files, thresh, text, ylabel, xlabel, ky, kx, ry, rx, overlays, graphs, split, hist, bins, log)
    
def thresh(a, key, split):
    return j.thresh(a, key, split)

# %%
files = []
files.append(['release/release1/*','release/release16/*','release/release64/*','release/release128/*','release/release256/*','release/release512/*', 'release/release0/*'])
files.append(['echo/deregister/*', 'echo/e/*', 'echo/echo/*', 'echo/register/*'])
files.append(['cops/delay/*', 'cops/deregister/*', 'cops/release/*', 'cops/tensec/*'])
files.append(['drx/cap/*'])
files.append(['ptau/capture/*'])
files = sum(files, [])
print(files)
# Out:
# ['release/release1/*', 'release/release16/*', 'release/release64/*', 'release/release128/*', 'release/release256/*', 'release/release512/*', 'release/release0/*', 'echo/deregister/*', 'echo/e/*', 'echo/echo/*', 'echo/register/*', 'cops/delay/*', 'cops/deregister/*', 'cops/release/*', 'cops/tensec/*', 'drx/cap/*', 'ptau/capture/*']

# %%
compare(files, thresh, 'UDP packet TX power vs ECL', 'TX power', 'ECL', 'TX power', 'ECL', 10, 1)
# Out:
# custom jupyter @DanielRobinson
# -11.65 24.65

# %%
compare(files, thresh, 'UDP packet latency vs Received Signal power', 'Latency (s)', 'RSRP (dBm)', 'txTime', 'Signal power', 1000, 10)
compare(files, thresh, 'Total energy vs Received Signal power', 'Energy (J)', 'RSRP (dBm)', 'energy', 'Signal power', 1000, 10)
compare(files, thresh, 'Total max current vs Received Signal power', 'Current (mA)', 'RSRP (dBm)', 'maxCurrent', 'Signal power', 1, 10)
compare(files, thresh, 'Total TX power vs Received Signal power', 'TX power (dBm)', 'RSRP (dBm)', 'TX power', 'Signal power', 10, 10)
compare(files, thresh, 'Total ECL vs Received Signal power', 'ECL', 'RSRP (dBm)', 'ECL', 'Signal power', 1, 10)
compare(files, thresh, 'Total PCI vs Received Signal power', 'PCI', 'RSRP (dBm)', 'PCI', 'Signal power', 1, 10)
compare(files, thresh, 'Total RSSI vs Received Signal power', 'RSSI (dBm)', 'RSRP (dBm)', 'Total power', 'Signal power', 10, 10)
compare(files, thresh, 'Total SNR vs Received Signal power', 'SNR (dB)', 'RSRP (dBm)', 'SNR', 'Signal power', 1, 10)
compare(files, thresh, 'Total SNR vs RSSI', 'SNR (dB)', 'RSSI (dBm)', 'SNR', 'Total power', 1, 10)
compare(files, thresh, 'Total RSRQ vs Received Signal power', 'RSRQ', 'RSRP (dBm)', 'RSRQ', 'Signal power', 1, 10)
compare(files, thresh, 'Total RSRQ vs RSSI', 'RSRQ', 'RSSI (dBm)', 'RSRQ', 'Total power', 1, 10)
compare(files, thresh, 'Total Energy vs SNR', 'Energy (J)', 'SNR (dB)', 'energy', 'SNR', 1000, 1)
# Out:
# custom jupyter @DanielRobinson
# -15.4353 325.3513
# custom jupyter @DanielRobinson
# 0.0 800.0
# custom jupyter @DanielRobinson
# 66.1 129.9
# custom jupyter @DanielRobinson
# -11.65 24.65
# custom jupyter @DanielRobinson
# -0.15000000000000002 3.15
# custom jupyter @DanielRobinson
# 1.89 128.6
# custom jupyter @DanielRobinson
# -115.82 -60.06
# custom jupyter @DanielRobinson
# -130.3 181.85
# custom jupyter @DanielRobinson
# -130.3 181.85
# custom jupyter @DanielRobinson
# -234.0 -102.0
# custom jupyter @DanielRobinson
# -234.0 -102.0
# custom jupyter @DanielRobinson
# 0.0 800.0

# %%
compare(files, thresh, 'UDP packet latency vs Received Signal power', 'Latency (s)', 'RSRP (dBm)', 'txTime', 'Signal power', 1000, 10, split=1, hist=True, log=True)
compare(files, thresh, 'Total energy vs Received Signal power', 'Energy (J)', 'RSRP (dBm)', 'energy', 'Signal power', 1000, 10, split=1, hist=True, log=True)
compare(files, thresh, 'Total max current vs Received Signal power', 'Current (mA)', 'RSRP (dBm)', 'maxCurrent', 'Signal power', 1, 10, split=1, hist=True, log=True)
compare(files, thresh, 'Total TX power vs Received Signal power', 'TX power (dBm)', 'RSRP (dBm)', 'TX power', 'Signal power', 10, 10, split=1, hist=True, log=True)
compare(files, thresh, 'Total ECL vs Received Signal power', 'ECL', 'RSRP (dBm)', 'ECL', 'Signal power', 1, 10, split=1, hist=True, log=True)
compare(files, thresh, 'Total PCI vs Received Signal power', 'PCI', 'RSRP (dBm)', 'PCI', 'Signal power', 1, 10, split=1, hist=True, log=True)
compare(files, thresh, 'Total RSSI vs Received Signal power', 'RSSI (dBm)', 'RSRP (dBm)', 'Total power', 'Signal power', 10, 10, split=1, hist=True, log=True)
compare(files, thresh, 'Total SNR vs Received Signal power', 'SNR (dB)', 'RSRP (dBm)', 'SNR', 'Signal power', 1, 10, split=1, hist=True, log=True)
compare(files, thresh, 'Total SNR vs RSSI', 'SNR (dB)', 'RSSI (dBm)', 'SNR', 'Total power', 1, 10, split=1, hist=True, log=True)
compare(files, thresh, 'Total RSRQ vs Received Signal power', 'RSRQ', 'RSRP (dBm)', 'RSRQ', 'Signal power', 1, 10, split=1, hist=True, log=True)
compare(files, thresh, 'Total RSRQ vs RSSI', 'RSRQ', 'RSSI (dBm)', 'RSRQ', 'Total power', 1, 10, split=1, hist=True, log=True)
compare(files, thresh, 'Total Energy vs SNR', 'Energy (J)', 'SNR (dB)', 'energy', 'SNR', 1000, 1, split=1, hist=True, log=True)
# Out:
# custom jupyter @DanielRobinson
# custom jupyter @DanielRobinson
# custom jupyter @DanielRobinson
# custom jupyter @DanielRobinson
# custom jupyter @DanielRobinson
# custom jupyter @DanielRobinson
# custom jupyter @DanielRobinson
# custom jupyter @DanielRobinson
# custom jupyter @DanielRobinson
# custom jupyter @DanielRobinson
# custom jupyter @DanielRobinson
# custom jupyter @DanielRobinson
