# %%
import numpy as np
import matplotlib.pyplot as plt
from process.jupyter import csvToDict

# %%
dirr = 'logs/vodacom/centurycity/ublox/'
def view(files, length=1000):
    dt = []
    for f in files:
        dt.append(dataProcess(csvToDict(dirr + f)))
    datasetPlot(dt, length)

# %%
# data = [dataProcess(csvToDict(dirr + 'cops/ant'))]
# datasetPlot(data)

# %%
view(['cops/ant'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6aaa9ccf5736> in <module>
# ----> 1 view(['cops/ant'])
#
# <ipython-input-2-df111545341d> in view(files, length)
#       3     dt = []
#       4     for f in files:
# ----> 5         dt.append(dataProcess(csvToDict(dirr + f)))
#       6     datasetPlot(dt, length)
#
# NameError: name 'dataProcess' is not defined

# %%
view(['cops/ant', 'cops/10', 'cops/20', 'cops/30', 'cops/40', 'cops/50', 'cops/60',], 3)
# Out:
# <class 'UnicodeDecodeError'>
# <class 'UnicodeDecodeError'>
# c:\users\d7rob\appdata\local\programs\python\python37\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# c:\users\d7rob\appdata\local\programs\python\python37\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
view(['cops/110', 'cops/failed/ant', 'cops/failed/40', 'cops/failed/80', 'cops/failed/110',  'cops/deregister/10', ])
# Out:
# <class 'UnicodeDecodeError'>
# <class 'UnicodeDecodeError'>
# <class 'UnicodeDecodeError'>
# <class 'UnicodeDecodeError'>

# %%
view(['drx/0', 'drx/10', 'drx/20', 'drx/30_2', 'drx/40', ], 10)
# Out:
# <class 'UnicodeDecodeError'>
# <class 'UnicodeDecodeError'>
# <class 'UnicodeDecodeError'>

# %%
view(['ptau/0', 'ptau/10', 'ptau/20', 'ptau/30', 'ptau/40', 'ptau/50'], 10)
# Out:
# <class 'UnicodeDecodeError'>
# <class 'UnicodeDecodeError'>
# <class 'UnicodeDecodeError'>
# <class 'UnicodeDecodeError'>

# %%
view(['echo/0', 'echo/10', 'echo/20', 'echo/30', 'echo/40', 'echo/50', 'echo/110'], 10)
# Out:
# <class 'UnicodeDecodeError'>
# <class 'UnicodeDecodeError'>
# <class 'UnicodeDecodeError'>

# %%
view(['release/release1/0', 'release/release1/10', 'release/release1/20', 'release/release1/30'], 10)
# Out:
# <class 'UnicodeDecodeError'>

# %%
view(['release/release512/0', 'release/release512/110', 'release/release512/20', 'release/release512/30', 'release/release512/40', 'release/release512/50', 'release/release512/60'], 10)
# Out:
# <class 'UnicodeDecodeError'>
# <class 'UnicodeDecodeError'>
