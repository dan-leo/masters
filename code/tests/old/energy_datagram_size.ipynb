# %%
importlib.reload(p)

# dirrs = ['logs/zte_mtn/rf_shield/ublox/', 'logs/zte_mtn/rf_shield/quectel/']
# dirrs = ['logs/zte_mtn/rf_shield/quectel/']
# dirrs = ['logs/ericsson_mtn/testplant_14th/ublox/', 'logs/ericsson_mtn/testplant_14th/quectel/', 'logs/huawei_vodacom/quellerina/ublox/', 'logs/huawei_vodacom/quellerina/quectel/',]
# dirrs = ['logs/zte_mtn/rf_shield/ublox/', 'logs/zte_mtn/rf_shield/quectel/', 'logs/nokia_vodacom/centurycity/ublox/', 'logs/nokia_vodacom/centurycity/quectel/']
dirrs = ['logs/ericsson_mtn/testplant_14th/ublox/', 'logs/huawei_vodacom/quellerina/ublox/', 'logs/zte_mtn/rf_shield/ublox/', 'logs/nokia_vodacom/centurycity/ublox/']
# dirrs = ['logs/ericsson_mtn/testplant_14th/quectel/', 'logs/huawei_vodacom/quellerina/quectel/', 'logs/zte_mtn/rf_shield/quectel/', 'logs/nokia_vodacom/centurycity/quectel/']

files = []
# files.append(['release/release1/*','release/release16/*','release/release64/*'])
# files.append(['release/release1/*','release/release16/*','release/release64/*','release/release128/*','release/release256/*','release/release512/*', 'release/release0/*'])
# files.append(['echo/deregister/*', 'echo/e/*', 'echo/echo/*', 'echo/register/*'])
# files.append(['cops/delay/*', 'cops/deregister/*', 'cops/release/*', 'cops/tensec/*'])
# files.append(['drx/cap/*'])
# files.append(['ptau/capture/*'])
files = sum(files, [])
print(files)

cc = ['tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:blue', 'tab:brown', 'tab:cyan']

ky = 'energy'
kx = 'SNR'

limited = True
# limited = False

thresh = plotlim = distlim = histlim = [None] * 4

thresh = [-2000, None, None, None]
scale = [20, 1000]

if limited:
    plotlim = [-20,  270, 0.3, 10]
    
dgrams = [1, 16, 64, 128, 256, 512]

fig = plt.figure(figsize=(6, 4))
for i, s in enumerate(dgrams):
    files = ['release/release' + str(s) + '/*']
    print(files)
    p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim, scale, limited, dirrs, files, title='', log=True, overlay=True, scaled=True, 
                    colour=cc, legend=True if not i else False, ttype='colour', fig=fig, offset=50*i, labels=['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB']) #, bbox=(1.05, 0.9))
ax = plt.gca()
ax.set_xticklabels([0] + dgrams)
print(plt.xticks())
# Out:
# plotter @Daniel.Robinson
# []
# ['release/release1/*']
# ['release/release16/*']
# ['release/release64/*']
# r [array([-1538.4, -1538.4]), array([11.798,  0.013])] 20 dB ['release/release64/*']
# ['release/release128/*']
# ['release/release256/*']
# ['release/release512/*']
# (array([-50.,   0.,  50., 100., 150., 200., 250., 300.]), <a list of 8 Text xticklabel objects>)

# %%
importlib.reload(p)

# dirrs = ['logs/zte_mtn/rf_shield/ublox/', 'logs/zte_mtn/rf_shield/quectel/']
# dirrs = ['logs/zte_mtn/rf_shield/quectel/']
# dirrs = ['logs/ericsson_mtn/testplant_14th/ublox/', 'logs/ericsson_mtn/testplant_14th/quectel/', 'logs/huawei_vodacom/quellerina/ublox/', 'logs/huawei_vodacom/quellerina/quectel/',]
# dirrs = ['logs/zte_mtn/rf_shield/ublox/', 'logs/zte_mtn/rf_shield/quectel/', 'logs/nokia_vodacom/centurycity/ublox/', 'logs/nokia_vodacom/centurycity/quectel/']
dirrs = ['logs/ericsson_mtn/testplant_14th/ublox/', 'logs/huawei_vodacom/quellerina/ublox/', 'logs/zte_mtn/rf_shield/ublox/', 'logs/nokia_vodacom/centurycity/ublox/']
dirrs = ['logs/ericsson_mtn/testplant_14th/quectel/', 'logs/huawei_vodacom/quellerina/quectel/', 'logs/zte_mtn/rf_shield/quectel/', 'logs/nokia_vodacom/centurycity/quectel/']

# files = []
# # files.append(['release/release1/*','release/release16/*','release/release64/*'])
# # files.append(['release/release1/*','release/release16/*','release/release64/*','release/release128/*','release/release256/*','release/release512/*', 'release/release0/*'])
# # files.append(['echo/deregister/*', 'echo/e/*', 'echo/echo/*', 'echo/register/*'])
# # files.append(['cops/delay/*', 'cops/deregister/*', 'cops/release/*', 'cops/tensec/*'])
# # files.append(['drx/cap/*'])
# # files.append(['ptau/capture/*'])
# files = sum(files, [])
# print('files', files)

cc = ['tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:blue', 'tab:brown', 'tab:cyan']

ky = 'energy'
kx = 'SNR'

limited = True
# limited = False

thresh = plotlim = distlim = histlim = [None] * 4

thresh = [-2000, None, None, None]
scale = [20, 1000]

if limited:
    plotlim = [-20,  270, 0.3, 10]
    
dgrams = [1, 16, 64, 128, 256, 512]

fig = plt.figure(figsize=(6, 4))
for i, s in enumerate(dgrams):
    files = ['release/release' + str(s) + '/*']
    print(files)
    p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim, scale, limited, dirrs, files, title='', log=True, overlay=True, scaled=True, 
                    colour=cc, legend=True if not i else False, ttype='colour', fig=fig, offset=50*i, labels=['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB']) #, bbox=(1.05, 0.9))
ax = plt.gca()
ax.set_xticklabels([0] + dgrams)
print(plt.xticks())
plt.ylabel('Energy (mJ)')
plt.xlabel('Datagram size (B)')
plt.savefig('../datagrams/quectel_sizes.png')
# Out:
# plotter @Daniel.Robinson
# ['release/release1/*']
# r [array([-1638.4]), array([0.])] 20 dB ['release/release1/*']
# r [array([-1638.4, -1638.4]), array([0., 0.])] 20 dB ['release/release1/*']
# r [array([-1638.4]), array([0.])] 20 dB ['release/release1/*']
# r [array([-1638.4]), array([0.])] 20 dB ['release/release1/*']
# ['release/release16/*']
# r [array([-1588.4]), array([0.])] 0 dB ['release/release16/*']
# r [array([-1588.4]), array([0.])] 20 dB ['release/release16/*']
# r [array([-1588.4]), array([0.])] 20 dB ['release/release16/*']
# r [array([-1588.4, -1588.4, -1588.4]), array([0., 0., 0.])] 20 dB ['release/release16/*']
# r [array([-1588.4]), array([0.])] 20 dB ['release/release16/*']
# ['release/release64/*']
# r [array([-1538.4]), array([0.])] 20 dB ['release/release64/*']
# r [array([-1538.4, -1538.4]), array([0., 0.])] 20 dB ['release/release64/*']
# ['release/release128/*']
# r [array([-1488.4]), array([1.098])] 10 dB ['release/release128/*']
# ...

# %%
importlib.reload(p)

# dirrs = ['logs/zte_mtn/rf_shield/ublox/', 'logs/zte_mtn/rf_shield/quectel/']
dirrs = ['logs/zte_mtn/rf_shield/ublox/']

files = []
# files.append(['release/release1/*','release/release16/*','release/release64/*'])
# files.append(['release/release1/*','release/release16/*','release/release64/*','release/release128/*','release/release256/*','release/release512/*', 'release/release0/*'])
# files.append(['echo/deregister/*', 'echo/e/*', 'echo/echo/*', 'echo/register/*'])
# files.append(['cops/delay/*', 'cops/deregister/*', 'cops/release/*', 'cops/tensec/*'])
# files.append(['drx/cap/*'])
# files.append(['ptau/capture/*'])
files = sum(files, [])
print(files)

cc = ['tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:blue', 'tab:brown', 'tab:cyan']

ky = 'energy'
kx = 'SNR'

limited = True
# limited = False

thresh = plotlim = distlim = histlim = [None] * 4

thresh = [-2000, None, None, None]
scale = [20, 1000]

if limited:
    plotlim = [-20,  270, 0.3, 10]
    
dgrams = [1, 16, 64, 128, 256, 512]

fig = plt.figure(figsize=(6, 4))
for i, s in enumerate(dgrams):
    files = ['release/release' + str(s) + '/*']
    print(files)
    p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim, scale, limited, dirrs, files, title='', log=True, overlay=True, scaled=True, 
                    colour=cc, labels=['0 dB', '10 dB', '20 dB', '30 dB', '40-110 dB'], 
                    legend=True if not i else False, ttype='colour', fig=fig, offset=50*i,) #, bbox=(1.05, 0.9))
ax = plt.gca()
ax.set_xticklabels([0] + dgrams)
print(plt.xticks())
# Out:
# plotter @Daniel.Robinson
# []
# ['release/release1/*']
# ['release/release16/*']
# ['release/release64/*']
# r [array([-1538.4, -1538.4]), array([11.798,  0.013])] 0 dB ['release/release64/*']
# ['release/release128/*']
# ['release/release256/*']
# ['release/release512/*']
# (array([-50.,   0.,  50., 100., 150., 200., 250., 300.]), <a list of 8 Text xticklabel objects>)

# %%
p.attdt()
# Out:
# {'0 dB': [],
#  '10 dB': [],
#  '20 dB': [],
#  '30 dB': [],
#  '40 dB': [],
#  '50 dB': [],
#  '60 dB': [],
#  '70 dB': [],
#  '80 dB': [],
#  '90 dB': [],
#  '100 dB': [],
#  '110 dB': []}

# %%
importlib.reload(p)

# dirrs = ['logs/zte_mtn/rf_shield/ublox/', 'logs/zte_mtn/rf_shield/quectel/']
dirrs = ['logs/ericsson_mtn/testplant_14th/ublox/', 'logs/huawei_vodacom/quellerina/ublox/', 'logs/zte_mtn/rf_shield/ublox/', 'logs/nokia_vodacom/centurycity/ublox/']
dirrs = ['logs/zte_mtn/rf_shield/ublox/', 'logs/ericsson_mtn/testplant_14th/ublox/']

files = []
# files.append(['release/release1/*','release/release16/*','release/release64/*'])
# files.append(['release/release1/*','release/release16/*','release/release64/*','release/release128/*','release/release256/*','release/release512/*', 'release/release0/*'])
# files.append(['echo/deregister/*', 'echo/e/*', 'echo/echo/*', 'echo/register/*'])
# files.append(['cops/delay/*', 'cops/deregister/*', 'cops/release/*', 'cops/tensec/*'])
# files.append(['drx/cap/*'])
# files.append(['ptau/capture/*'])
files = sum(files, [])
print(files)

cc = ['tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:blue', 'tab:brown', 'tab:cyan']

ky = 'energy'
kx = 'SNR'

limited = True
# limited = False

thresh = plotlim = distlim = histlim = [None] * 4

thresh = [-2000, None, None, None]
scale = [20, 1000]

if limited:
    plotlim = [-20,  270, 0.3, 10]
    
dgrams = [1, 16, 64, 128, 256, 512]

fig = plt.figure(figsize=(6, 4))
for i, s in enumerate(dgrams):
    files = ['release/release' + str(s) + '/*']
    print(files)
    p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim, scale, limited, dirrs, files, title='', log=True, overlay=True, scaled=True, 
                    colour=cc, labels=[k for k in p.attdt()], legend=True if not i else False, ttype='colour', fig=fig, offset=50*i) #, bbox=(1.05, 0.9))
ax = plt.gca()
ax.set_xticklabels([0] + dgrams)
print(plt.xticks())
# Out:
# plotter @Daniel.Robinson
# []
# ['release/release1/*']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-59-79e707c46e0e> in <module>
#      38     print(files)
#      39     p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim, scale, limited, dirrs, files, title='', log=True, overlay=True, scaled=True,
# ---> 40                     colour=cc, labels=[k for k in p.attdt()], legend=True if not i else False, ttype='colour', fig=fig, offset=50*i) #, bbox=(1.05, 0.9))
#      41 ax = plt.gca()
#      42 ax.set_xticklabels([0] + dgrams)
#
# /mnt/c/GIT/masters/code/tests/plotter.py in scatternuator(name, kx, ky, thresh, plotlim, scale, limited, dirrs, files, kz, atd, scaled, log, overlay, labels, legend, title, ttype, fig, offset, colour, fx, fy, print_outliers, mean, bbox)
#     254             # print('legend', dirrs[di])
# ...

# %%
plotlim = [-20,  270, 350, 1500]
scale = [20, 1]
    
dgrams = [1, 16, 64, 128, 256, 512]

fig = plt.figure(figsize=(6, 4))
for i, s in enumerate(dgrams):
    files = ['release/release' + str(s) + '/*']
    p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim, scale, limited, dirrs, files, title='', log=False, overlay=True, scaled=True, 
                colour=cc, labels=[k for k in p.attdt()], legend=True if not i else False, ttype='colour', fig=fig, offset=50*i) #, bbox=(1.05, 0.9))
ax = plt.gca()
ax.set_xticklabels([0] + dgrams)
print(plt.xticks())
ax.set_xlabel('Datagram size (B)')
ax.set_ylabel('Energy (mJ)')
plt.savefig('datagrams/mtn_ublox_energy.png')
plt.savefig('datagrams/mtn_ublox_energy.pdf')
# Out:
# r [array([-1638.4, -1638.4]), array([29.69, 30.04])] 0 dB ['release/release1/*']
# r [array([-1538.4, -1538.4]), array([11797.88,    13.08])] 0 dB ['release/release64/*']
# (array([-50.,   0.,  50., 100., 150., 200., 250., 300.]), <a list of 8 Text xticklabel objects>)

# %%
dirrs = ['logs/zte_mtn/rf_shield/quectel/']
scale = [20, 1000]
plotlim = [-20,  270, 0.3, 10]
dgrams = [1, 16, 64, 128, 256, 512]
fig = plt.figure(figsize=(6, 4))
for i, s in enumerate(dgrams):
    files = ['release/release' + str(s) + '/*']
    p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim, scale, limited, dirrs, files, log=True, overlay=True, scaled=True, labels=['Ublox' + str(s)], legend=True if not i else False, ttype='colour', fig=fig, offset=50*i) #, bbox=(1.05, 0.9))
ax = plt.gca()
ax.set_xticklabels([0] + dgrams)
print(plt.xticks())
# Out:
# r [array([-1638.4]), array([0.])] Ublox1 ['release/release1/*']
# r [array([-1638.4, -1638.4]), array([0., 0.])] Ublox1 ['release/release1/*']
# r [array([-1638.4]), array([0.])] Ublox1 ['release/release1/*']
# r [array([-1638.4]), array([0.])] Ublox1 ['release/release1/*']
# r [array([-1638.4, -1638.4]), array([0., 0.])] Ublox1 ['release/release1/*']
# r [array([-1588.4]), array([0.])] Ublox16 ['release/release16/*']
# r [array([-1588.4]), array([0.])] Ublox16 ['release/release16/*']
# r [array([-1588.4, -1588.4, -1588.4]), array([0., 0., 0.])] Ublox16 ['release/release16/*']
# r [array([-1588.4]), array([0.])] Ublox16 ['release/release16/*']
# r [array([-1538.4]), array([0.])] Ublox64 ['release/release64/*']
# r [array([-1538.4, -1538.4]), array([0., 0.])] Ublox64 ['release/release64/*']
# r [array([-1538.4]), array([0.])] Ublox64 ['release/release64/*']
# r [array([-1488.4]), array([0.])] Ublox128 ['release/release128/*']
# ...

# %%
dirrs = ['logs/zte_mtn/rf_shield/quectel/']
scale = [20, 1]
plotlim = [-20,  270, 300, 1800]
dgrams = [1, 16, 64, 128, 256, 512]
fig = plt.figure(figsize=(6, 4))
for i, s in enumerate(dgrams):
    files = ['release/release' + str(s) + '/*']
    p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim, scale, limited, dirrs, files, log=False, overlay=True, scaled=True, labels=['Ublox' + str(s)], legend=True if not i else False, ttype='colour', fig=fig, offset=50*i) #, bbox=(1.05, 0.9))
ax = plt.gca()
ax.set_xticklabels([0] + dgrams)
print(plt.xticks())
# Out:
# r [array([-1638.4]), array([0.])] Ublox1 ['release/release1/*']
# r [array([-1638.4, -1638.4]), array([0., 0.])] Ublox1 ['release/release1/*']
# r [array([-1638.4]), array([0.])] Ublox1 ['release/release1/*']
# r [array([-1638.4]), array([0.])] Ublox1 ['release/release1/*']
# r [array([-1638.4, -1638.4]), array([0., 0.])] Ublox1 ['release/release1/*']
# r [array([-1588.4]), array([0.])] Ublox16 ['release/release16/*']
# r [array([-1588.4]), array([0.])] Ublox16 ['release/release16/*']
# r [array([-1588.4, -1588.4, -1588.4]), array([0., 0., 0.])] Ublox16 ['release/release16/*']
# r [array([-1588.4]), array([0.])] Ublox16 ['release/release16/*']
# r [array([-1538.4]), array([0.])] Ublox64 ['release/release64/*']
# r [array([-1538.4, -1538.4]), array([0., 0.])] Ublox64 ['release/release64/*']
# r [array([-1538.4]), array([0.])] Ublox64 ['release/release64/*']
# r [array([-1488.4]), array([0.])] Ublox128 ['release/release128/*']
# ...

# %%
dirrs = ['logs/nokia_vodacom/centurycity/ublox/']
scale = [20, 1000]
plotlim = [-20,  270, 4, 100]
dgrams = [1, 16, 64, 128, 256, 512]
fig = plt.figure(figsize=(6, 4))
for i, s in enumerate(dgrams):
    files = ['release/release' + str(s) + '/*']
    p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim, scale, limited, dirrs, files, log=True, overlay=True, scaled=True, labels=['Ublox' + str(s)], legend=True if not i else False, ttype='colour', fig=fig, offset=50*i) #, bbox=(1.05, 0.9))
ax = plt.gca()
ax.set_xticklabels([0] + dgrams)
print(plt.xticks())
# Out:
# (array([-50.,   0.,  50., 100., 150., 200., 250., 300.]), <a list of 8 Text xticklabel objects>)

# %%
dirrs = ['logs/nokia_vodacom/centurycity/quectel/']
scale = [20, 1000]
plotlim = [-20,  270, 4, 100]
dgrams = [1, 16, 64, 128, 256, 512]
fig = plt.figure(figsize=(6, 4))
for i, s in enumerate(dgrams):
    files = ['release/release' + str(s) + '/*']
    p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim, scale, limited, dirrs, files, log=True, overlay=True, labels=['Ublox' + str(s)], legend=True if not i else False, type='colour', fig=fig, offset=50*i) #, bbox=(1.05, 0.9))
ax = plt.gca()
ax.set_xticklabels([0] + dgrams)
print(plt.xticks())
# Out:
# logs/nokia_vodacom/centurycity/quectel/
# logs/nokia_vodacom/centurycity/quectel/
# logs/nokia_vodacom/centurycity/quectel/
# logs/nokia_vodacom/centurycity/quectel/
# logs/nokia_vodacom/centurycity/quectel/
# logs/nokia_vodacom/centurycity/quectel/
# (array([-50.,   0.,  50., 100., 150., 200., 250., 300.]), <a list of 8 Text xticklabel objects>)
