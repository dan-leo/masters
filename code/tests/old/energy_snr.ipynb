# %%
import numpy as np
import matplotlib.pyplot as plt
import jupyter as j
import importlib
import pandas as pd
import seaborn as sns
importlib.reload(j)

import matplotlib.ticker as ticker
import glob

import plotter as p
importlib.reload(p)

dirrs = ['logs/zte_mtn/rf_shield/ublox/', 'logs/zte_mtn/rf_shield/quectel/', 'logs/nokia_vodacom/centurycity/ublox/', 'logs/nokia_vodacom/centurycity/quectel/']
# Out:
# plotter @Daniel.Robinson

# %%
# p.scatternuator('energy_snr_' + ky, dirrs, files, kx, ky, thresh, plotlim, scale, limited, bins=40)

# %%
importlib.reload(p)

dirrs = ['logs/zte_mtn/rf_shield/ublox/', 'logs/zte_mtn/rf_shield/quectel/']

files = []
files.append(['release/release1/*','release/release16/*','release/release64/*','release/release128/*','release/release256/*','release/release512/*', 'release/release0/*'])
# files.append(['echo/deregister/*', 'echo/e/*', 'echo/echo/*', 'echo/register/*'])
# files.append(['cops/delay/*', 'cops/deregister/*', 'cops/release/*', 'cops/tensec/*'])
# files.append(['drx/cap/*'])
# files.append(['ptau/capture/*'])
files = sum(files, [])
print(files)

# atd = p.db(dirrs, files)

ky = 'energy'
kx = 'SNR'

limited = True
limited = False

thresh = plotlim = distlim = histlim = [None] * 4

thresh = [-2000, None, None, None]
scale = [1, 1000]

# x = 0.0001
# y = 2000

# x = 0.1
# y = 100

# percx = 0.0001
# percy = 0.2

if limited:
    plotlim = [-40,  140, 0.3, 10]
#     distlim = [x, y, percx, percy]
#     histlim = [x, y, percx*10, 600]
# plotlim= [-132.89636  232.16162   22.74492  899.94846]
# distlim= [-116.31505  818.21088    0.         0.14138]
# distlim= [   0.63736 1088.00872    0.         0.14138]
# histlim= [   0.00013 1631.65884    0.       571.11423]

# p.pan4('energy_snr_' + ky, dirrs, files, kx, ky, thresh, plotlim, distlim, histlim, scale, limited, bins=40)

p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim, scale, limited, dirrs, files, 
                labels=['A', 'B', 'C', 'D'], colour=['tab:blue', 'tab:red', 'tab:green', 'tab:orange'], 
                log=True, overlay=True, bbox=(1.05, 0.9))
plotlim = [-40,  140, 100, 1500]
scale = [1, 1]
# p.scatternuator('energy_snr_zte' + ky, kx, ky, thresh, plotlim, scale, limited, dirrs, files, log=False, overlay=True, bbox=(1.05, 0.9))
p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim, scale, limited, dirrs, files, 
                labels=['A', 'B', 'C', 'D'], colour=['tab:blue', 'tab:red', 'tab:green', 'tab:orange'], 
                log=False, overlay=True, bbox=(1.05, 0.9))
# Out:
# plotter @Daniel.Robinson
# ['release/release1/*', 'release/release16/*', 'release/release64/*', 'release/release128/*', 'release/release256/*', 'release/release512/*', 'release/release0/*']
# KeyError, IndexError list index out of range 0 dB A ['release/release1/*', 'release/release16/*', 'release/release64/*', 'release/release128/*', 'release/release256/*', 'release/release512/*', 'release/release0/*']
# r [array([-32768., -32768.]), array([29.69, 30.04])] A ['release/release1/*', 'release/release16/*', 'release/release64/*', 'release/release128/*', 'release/release256/*', 'release/release512/*', 'release/release0/*']
# KeyError, IndexError list index out of range 0 dB B ['release/release1/*', 'release/release16/*', 'release/release64/*', 'release/release128/*', 'release/release256/*', 'release/release512/*', 'release/release0/*']
# ...

# %%
importlib.reload(p)

dirrs = ['logs/zte_mtn/rf_shield/ublox/', 'logs/zte_mtn/rf_shield/quectel/']

files = []
files.append(['release/release1/*','release/release16/*','release/release64/*','release/release128/*','release/release256/*','release/release512/*', 'release/release0/*'])
# files.append(['echo/deregister/*', 'echo/e/*', 'echo/echo/*', 'echo/register/*'])
# files.append(['cops/delay/*', 'cops/deregister/*', 'cops/release/*', 'cops/tensec/*'])
# files.append(['drx/cap/*'])
# files.append(['ptau/capture/*'])
files = sum(files, [])
print(files)

# atd = p.db(dirrs, files)

ky = 'energy'
kx = 'SNR'

limited = True
# limited = False

thresh = plotlim = distlim = histlim = [None] * 4

thresh = [-2000, None, None, None]
scale = [1, 1000]

# x = 0.0001
# y = 2000

# x = 0.1
# y = 100

# percx = 0.0001
# percy = 0.2

if limited:
    plotlim = [-40,  140, 0.3, 10]
#     distlim = [x, y, percx, percy]
#     histlim = [x, y, percx*10, 600]
# plotlim= [-132.89636  232.16162   22.74492  899.94846]
# distlim= [-116.31505  818.21088    0.         0.14138]
# distlim= [   0.63736 1088.00872    0.         0.14138]
# histlim= [   0.00013 1631.65884    0.       571.11423]

# p.pan4('energy_snr_' + ky, dirrs, files, kx, ky, thresh, plotlim, distlim, histlim, scale, limited, bins=40)

p.scatternuator('energy_snr_zte_log' + ky, kx, ky, thresh, plotlim, scale, limited, dirrs, files, log=True, overlay=True, bbox=(1.05, 0.9))
plotlim = [-40,  140, 100, 1500]
scale = [1, 1]
p.scatternuator('energy_snr_zte' + ky, kx, ky, thresh, plotlim, scale, limited, dirrs, files, log=False, overlay=True, bbox=(1.05, 0.9))
# Out:
# ['release/release1/*', 'release/release16/*', 'release/release64/*', 'release/release128/*', 'release/release256/*', 'release/release512/*', 'release/release0/*']
# logs/zte_mtn/rf_shield/ublox/
# logs/zte_mtn/rf_shield/quectel/
# 'SNR'
# logs/zte_mtn/rf_shield/ublox/
# logs/zte_mtn/rf_shield/quectel/
# 'SNR'

# %%
importlib.reload(p)
scale = [1, 1000]
dirrs = ['logs/nokia_vodacom/centurycity/ublox/', 'logs/nokia_vodacom/centurycity/quectel/']
plotlim = [-80,  140, 4, 100]
p.scatternuator('energy_snr_nokia_log' + ky, kx, ky, thresh, plotlim, scale, limited, dirrs, files, log=True, overlay=True)
plotlim = [-80,  140, 0, 100]
p.scatternuator('energy_snr_nokia' + ky, kx, ky, thresh, plotlim, scale, limited, dirrs, files, log=False, overlay=True)
# Out:
# logs/nokia_vodacom/centurycity/ublox/
# logs/nokia_vodacom/centurycity/quectel/
# 'SNR'
# logs/nokia_vodacom/centurycity/ublox/
# logs/nokia_vodacom/centurycity/quectel/
# 'SNR'

# %%
# fig = plt.figure()
# ax = fig.add_subplot?
